# %% [markdown]
# **Problem Statement**:-Predicting if a person would buy life insurnace based on his age using logistic regression

# %%
# Import Necessary Libraries
import pandas as pd
import pandas as np

import warnings as warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %%
# Import Data file
df = pd.read_csv("/content/insurance_data.csv")

# %%
# check  The Data set
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
# Check number of rows and columns present in data set
df.shape
# Out:
# (27, 2)

# %% [markdown]
# --> So, There are total 27 rows and 2 columns present in or data set

# %%
# Check type of data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
# Check Is there any missing values present in data set
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %% [markdown]
# *   There are **NO** missing values present in our data set

# %%
# Check is there Null Values Presnt in our data set
df.isna().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %% [markdown]
# *  There is **NO** Null data present in our data set

# %%
# Now, prepeare the scatter plot to our data set
df.plot(kind='scatter', x='age', y='bought_insurance',marker = '*',color = 'black',linewidth=2)
# Out:
# <Axes: xlabel='age', ylabel='bought_insurance'>

# %%
# spliting our data in to train and test split
X_train,X_test,y_train,y_test =train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
# now Check the data for train and test size
X_test
# Out:
#     age
# 0    22
# 23   45
# 18   19
# 14   49
# 6    55
# 7    60

# %%
# import Logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# Now Fit the Model
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# now Predect the model
y_pred = model.predict(X_test)

# %%
X_test
# Out:
#     age
# 0    22
# 23   45
# 18   19
# 14   49
# 6    55
# 7    60

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0, 1, 1, 1])

# %%
# Check The scores
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
# Check the coeffiecient
model.coef_
# Out:
# array([[0.15550954]])

# %%
model.intercept_
# Out:
# array([-5.79177751])

# %%
# Define Sigmoid function
import math
def sigmoid(X):
  return 1/(1+math.exp(-X))

# %%
def predection_function(age):
  z = 0.1555 * age -5.79177
  y = sigmoid(z)
  return y

# %%
age = 37
predection_function(age)
# Out:
# 0.490433667536718

# %%
age = 38
predection_function(age)
# Out:
# 0.529273981958705

# %% [markdown]
# **0.49 is less than 0.5 which means person with 37 age will not buy insurance**
